# %%
import os
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from splinter import Browser
import time
from selenium import webdriver

# %%
background_df = pd.read_csv("./Resources/firearm-bc.csv")
background_df
# Out:
#          month          state   permit  permit_recheck  handgun  long_gun  \
# 0      2022-08        Alabama  20271.0           326.0  18400.0   13679.0
# 1      2022-08         Alaska    291.0            16.0   3225.0    3005.0
# 2      2022-08        Arizona   8278.0          2029.0  19079.0    9304.0
# 3      2022-08       Arkansas   2585.0           334.0   6885.0    5697.0
# 4      2022-08     California  39274.0         14674.0  39236.0   25005.0
# ...        ...            ...      ...             ...      ...       ...
# 15725  1998-11       Virginia      0.0             NaN     14.0       2.0
# 15726  1998-11     Washington      1.0             NaN     65.0     286.0
# 15727  1998-11  West Virginia      3.0             NaN    149.0     251.0
# 15728  1998-11      Wisconsin      0.0             NaN     25.0     214.0
# 15729  1998-11        Wyoming      8.0             NaN     45.0      49.0
#
#         other  multiple  admin  prepawn_handgun  ...  returned_other  \
# 0      1315.0      1074    0.0             15.0  ...             0.0
# 1       373.0       208    0.0              2.0  ...             0.0
# 2      1947.0      1239    0.0              7.0  ...             2.0
# 3       516.0       427   14.0              8.0  ...             0.0
# 4      5743.0         0    0.0              0.0  ...            82.0
# ...       ...       ...    ...              ...  ...             ...
# 15725     NaN         8    0.0              NaN  ...             NaN
# 15726     NaN         8    1.0              NaN  ...             NaN
# 15727     NaN         5    0.0              NaN  ...             NaN
# 15728     NaN         2    0.0              NaN  ...             NaN
# 15729     NaN         5    0.0              NaN  ...             NaN
#
#        rentals_handgun  rentals_long_gun  private_sale_handgun  \
# 0                  0.0               0.0                  28.0
# 1                  0.0               0.0                   4.0
# 2                  0.0               0.0                  12.0
# 3                  0.0               0.0                   7.0
# 4                  0.0               0.0                7708.0
# ...                ...               ...                   ...
# 15725              NaN               NaN                   NaN
# 15726              NaN               NaN                   NaN
# 15727              NaN               NaN                   NaN
# 15728              NaN               NaN                   NaN
# 15729              NaN               NaN                   NaN
#
#        private_sale_long_gun  private_sale_other  return_to_seller_handgun  \
# 0                       25.0                 3.0                       0.0
# 1                        2.0                 0.0                       1.0
# 2                        6.0                 2.0                       0.0
# 3                        8.0                 1.0                       0.0
# 4                     3463.0               647.0                      15.0
# ...                      ...                 ...                       ...
# 15725                    NaN                 NaN                       NaN
# 15726                    NaN                 NaN                       NaN
# 15727                    NaN                 NaN                       NaN
# 15728                    NaN                 NaN                       NaN
# 15729                    NaN                 NaN                       NaN
#
#        return_to_seller_long_gun  return_to_seller_other  totals
# 0                            1.0                     0.0   58549
# 1                            0.0                     0.0    7400
# 2                            0.0                     0.0   43789
# 3                            1.0                     0.0   18508
# 4                           19.0                    18.0  138358
# ...                          ...                     ...     ...
# 15725                        NaN                     NaN      24
# 15726                        NaN                     NaN     361
# 15727                        NaN                     NaN     408
# 15728                        NaN                     NaN     241
# 15729                        NaN                     NaN     107
#
# [15730 rows x 27 columns]

# %%
#reducing the DF
short_df = background_df[["month", "state","permit","permit_recheck","handgun","long_gun", "other", "multiple"]].copy()

short_df
# Out:
#          month          state   permit  permit_recheck  handgun  long_gun  \
# 0      2022-08        Alabama  20271.0           326.0  18400.0   13679.0
# 1      2022-08         Alaska    291.0            16.0   3225.0    3005.0
# 2      2022-08        Arizona   8278.0          2029.0  19079.0    9304.0
# 3      2022-08       Arkansas   2585.0           334.0   6885.0    5697.0
# 4      2022-08     California  39274.0         14674.0  39236.0   25005.0
# ...        ...            ...      ...             ...      ...       ...
# 15725  1998-11       Virginia      0.0             NaN     14.0       2.0
# 15726  1998-11     Washington      1.0             NaN     65.0     286.0
# 15727  1998-11  West Virginia      3.0             NaN    149.0     251.0
# 15728  1998-11      Wisconsin      0.0             NaN     25.0     214.0
# 15729  1998-11        Wyoming      8.0             NaN     45.0      49.0
#
#         other  multiple
# 0      1315.0      1074
# 1       373.0       208
# 2      1947.0      1239
# 3       516.0       427
# 4      5743.0         0
# ...       ...       ...
# 15725     NaN         8
# 15726     NaN         8
# 15727     NaN         5
# 15728     NaN         2
# 15729     NaN         5
#
# [15730 rows x 8 columns]

# %%
#drop row with NAN
reduced_df = short_df.dropna()
reduced_df
# Out:
#         month          state   permit  permit_recheck  handgun  long_gun  \
# 0     2022-08        Alabama  20271.0           326.0  18400.0   13679.0
# 1     2022-08         Alaska    291.0            16.0   3225.0    3005.0
# 2     2022-08        Arizona   8278.0          2029.0  19079.0    9304.0
# 3     2022-08       Arkansas   2585.0           334.0   6885.0    5697.0
# 4     2022-08     California  39274.0         14674.0  39236.0   25005.0
# ...       ...            ...      ...             ...      ...       ...
# 4340  2016-02       Virginia    784.0             0.0  30085.0   15948.0
# 4341  2016-02     Washington  15736.0             0.0  20583.0   11991.0
# 4342  2016-02  West Virginia   3527.0             0.0  10746.0    7436.0
# 4343  2016-02      Wisconsin   9420.0             0.0  19465.0   12431.0
# 4344  2016-02        Wyoming    551.0             0.0   2287.0    2036.0
#
#        other  multiple
# 0     1315.0      1074
# 1      373.0       208
# 2     1947.0      1239
# 3      516.0       427
# 4     5743.0         0
# ...      ...       ...
# 4340  1133.0         0
# 4341  1832.0       863
# 4342   357.0       757
# 4343   821.0        62
# 4344   139.0       150
#
# [4345 rows x 8 columns]

# %%
month_df=reduced_df['month'].str.split('-', expand=True)
year_df= month_df.rename(columns={0: "Year"})
year_df
# Out:
#       Year   1
# 0     2022  08
# 1     2022  08
# 2     2022  08
# 3     2022  08
# 4     2022  08
# ...    ...  ..
# 4340  2016  02
# 4341  2016  02
# 4342  2016  02
# 4343  2016  02
# 4344  2016  02
#
# [4345 rows x 2 columns]

# %%
y_df= year_df[["Year"]].copy()
y_df
# Out:
#       Year
# 0     2022
# 1     2022
# 2     2022
# 3     2022
# 4     2022
# ...    ...
# 4340  2016
# 4341  2016
# 4342  2016
# 4343  2016
# 4344  2016
#
# [4345 rows x 1 columns]

# %%
joined_df=reduced_df.join(y_df)
joined_df
# Out:
#         month          state   permit  permit_recheck  handgun  long_gun  \
# 0     2022-08        Alabama  20271.0           326.0  18400.0   13679.0
# 1     2022-08         Alaska    291.0            16.0   3225.0    3005.0
# 2     2022-08        Arizona   8278.0          2029.0  19079.0    9304.0
# 3     2022-08       Arkansas   2585.0           334.0   6885.0    5697.0
# 4     2022-08     California  39274.0         14674.0  39236.0   25005.0
# ...       ...            ...      ...             ...      ...       ...
# 4340  2016-02       Virginia    784.0             0.0  30085.0   15948.0
# 4341  2016-02     Washington  15736.0             0.0  20583.0   11991.0
# 4342  2016-02  West Virginia   3527.0             0.0  10746.0    7436.0
# 4343  2016-02      Wisconsin   9420.0             0.0  19465.0   12431.0
# 4344  2016-02        Wyoming    551.0             0.0   2287.0    2036.0
#
#        other  multiple  Year
# 0     1315.0      1074  2022
# 1      373.0       208  2022
# 2     1947.0      1239  2022
# 3      516.0       427  2022
# 4     5743.0         0  2022
# ...      ...       ...   ...
# 4340  1133.0         0  2016
# 4341  1832.0       863  2016
# 4342   357.0       757  2016
# 4343   821.0        62  2016
# 4344   139.0       150  2016
#
# [4345 rows x 9 columns]

# %%
cutting_df=joined_df.drop(["month"], axis=1)
cutting_df
# Out:
#               state   permit  permit_recheck  handgun  long_gun   other  \
# 0           Alabama  20271.0           326.0  18400.0   13679.0  1315.0
# 1            Alaska    291.0            16.0   3225.0    3005.0   373.0
# 2           Arizona   8278.0          2029.0  19079.0    9304.0  1947.0
# 3          Arkansas   2585.0           334.0   6885.0    5697.0   516.0
# 4        California  39274.0         14674.0  39236.0   25005.0  5743.0
# ...             ...      ...             ...      ...       ...     ...
# 4340       Virginia    784.0             0.0  30085.0   15948.0  1133.0
# 4341     Washington  15736.0             0.0  20583.0   11991.0  1832.0
# 4342  West Virginia   3527.0             0.0  10746.0    7436.0   357.0
# 4343      Wisconsin   9420.0             0.0  19465.0   12431.0   821.0
# 4344        Wyoming    551.0             0.0   2287.0    2036.0   139.0
#
#       multiple  Year
# 0         1074  2022
# 1          208  2022
# 2         1239  2022
# 3          427  2022
# 4            0  2022
# ...        ...   ...
# 4340         0  2016
# 4341       863  2016
# 4342       757  2016
# 4343        62  2016
# 4344       150  2016
#
# [4345 rows x 8 columns]

# %%
total_states = cutting_df["state"].nunique()
total_states
# Out:
# 55

# %%
grouped_state_df = cutting_df.groupby(["state"])

# %%
total_permit =grouped_state_df["permit"].sum()

# %%
total_permit_recheck =grouped_state_df["permit_recheck"].sum()

# %%
total_handgun =grouped_state_df["handgun"].sum()

# %%
total_long_gun =grouped_state_df["long_gun"].sum()

# %%
total_other =grouped_state_df["other"].sum()

# %%
total_multiple =grouped_state_df["multiple"].sum()

# %%
Check_Summary_df = pd.DataFrame({"Total permit" : total_permit,
      "Total permit_recheck" : total_permit_recheck,
      "Total handgun" : total_handgun,
      "Total long_gun" : total_long_gun,
      "Total other" : total_other,
      "Total multiple" : total_multiple,
      })
#Check_Summary_df
Check_Summary_df.reset_index().head()
# Out:
#         state  Total permit  Total permit_recheck  Total handgun  \
# 0     Alabama     2101078.0               23815.0      1281150.0
# 1      Alaska       17555.0                1243.0       243305.0
# 2     Arizona      564451.0               49883.0      1385488.0
# 3    Arkansas      293123.0               55598.0       580778.0
# 4  California     3271982.0              236306.0      3439158.0
#
#    Total long_gun  Total other  Total multiple
# 0        924019.0      72211.0           60042
# 1        227508.0      25263.0           16442
# 2        744420.0     118083.0           87491
# 3        528715.0      30917.0           33579
# 4       2433618.0     539235.0              11

# %% [markdown]
# # Visiting the URL for the St Louis Fed site using splinter

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url ="https://fred.stlouisfed.org/release/tables?rid=249&eid=259515&od=2016-01-01"
browser.visit(url)
data0_df = pd.read_html(url)
df_0=data0_df[0]
df_0.columns = ["Unnamed: 0_level_1","Name","2016","Preceding Period","Year Ago from Period"]
df_0.head()
# Out:
#    Unnamed: 0_level_1               Name   2016  Preceding Period  \
# 0                 NaN  The United States  66657             64631
# 1                 NaN            Alabama  53314             50900
# 2                 NaN             Alaska  85494             85898
# 3                 NaN            Arizona  64468             59751
# 4                 NaN           Arkansas  51830             48944
#
#    Year Ago from Period
# 0                 64631
# 1                 50900
# 2                 85898
# 3                 59751
# 4                 48944

# %%
reduce0_df=df_0.drop(["Unnamed: 0_level_1","Year Ago from Period"], axis=1)
#reduce0_df.head()
rename0_df = reduce0_df.rename(columns={"Name":"States","2016":"AVG_income_2016","Preceding Period":"AVG_income_2015"})
rename0_df.head()
# Out:
#               States  AVG_income_2016  AVG_income_2015
# 0  The United States            66657            64631
# 1            Alabama            53314            50900
# 2             Alaska            85494            85898
# 3            Arizona            64468            59751
# 4           Arkansas            51830            48944

# %%
drop0_df=rename0_df.drop(labels=0)
drop0_df.set_index('States',inplace=True)
#drop0_df.head()
drop0_df.reset_index().head()
# Out:
#        States  AVG_income_2016  AVG_income_2015
# 0     Alabama            53314            50900
# 1      Alaska            85494            85898
# 2     Arizona            64468            59751
# 3    Arkansas            51830            48944
# 4  California            75235            72774

# %%
url_1 ="https://fred.stlouisfed.org/release/tables?rid=249&eid=259515&od=2018-01-01"
browser.visit(url_1)
data1_df = pd.read_html(url_1)
df_1=data1_df[0]
df_1.columns = ["Unnamed: 0_level_1","Name","2018","Preceding Period","Year Ago from Period"]
df_1.head()
# Out:
#    Unnamed: 0_level_1               Name   2018  Preceding Period  \
# 0                 NaN  The United States  68168             67571
# 1                 NaN            Alabama  53879             56219
# 2                 NaN             Alaska  74161             86196
# 3                 NaN            Arizona  67201             65984
# 4                 NaN           Arkansas  53712             54988
#
#    Year Ago from Period
# 0                 67571
# 1                 56219
# 2                 86196
# 3                 65984
# 4                 54988

# %%
reduce1_df=df_1.drop(["Unnamed: 0_level_1","Year Ago from Period"], axis=1)
#reduce1_df.head()
rename1_df = reduce1_df.rename(columns={"Name":"States","2018":"AVG_income_2018","Preceding Period":"AVG_income_2017"})
rename1_df.head()
# Out:
#               States  AVG_income_2018  AVG_income_2017
# 0  The United States            68168            67571
# 1            Alabama            53879            56219
# 2             Alaska            74161            86196
# 3            Arizona            67201            65984
# 4           Arkansas            53712            54988

# %%
drop1_df=rename1_df.drop(labels=0)
drop1_df.set_index('States',inplace=True)
#drop1_df.head()
drop1_df.reset_index().head()
# Out:
#        States  AVG_income_2018  AVG_income_2017
# 0     Alabama            53879            56219
# 1      Alaska            74161            86196
# 2     Arizona            67201            65984
# 3    Arkansas            53712            54988
# 4  California            76055            77410

# %%
url_2 ="https://fred.stlouisfed.org/release/tables?rid=249&eid=259515&od=2020-01-01"
browser.visit(url_2)
data2_df = pd.read_html(url_2)
df_2=data2_df[0]
df_2.columns = ["Unnamed: 0_level_1","Name","2020","Preceding Period","Year Ago from Period"]
df_2.head()
# Out:
#    Unnamed: 0_level_1               Name   2020  Preceding Period  \
# 0                 NaN  The United States  71186             72808
# 1                 NaN            Alabama  57243             59558
# 2                 NaN             Alaska  78236             83079
# 3                 NaN            Arizona  70220             74897
# 4                 NaN           Arkansas  53148             57799
#
#    Year Ago from Period
# 0                 72808
# 1                 59558
# 2                 83079
# 3                 74897
# 4                 57799

# %%
reduce2_df=df_2.drop(["Unnamed: 0_level_1","Year Ago from Period"], axis=1)
#reduce2_df.head()
rename2_df = reduce2_df.rename(columns={"Name":"States","2020":"AVG_income_2020","Preceding Period":"AVG_income_2019"})
rename2_df.head()
# Out:
#               States  AVG_income_2020  AVG_income_2019
# 0  The United States            71186            72808
# 1            Alabama            57243            59558
# 2             Alaska            78236            83079
# 3            Arizona            70220            74897
# 4           Arkansas            53148            57799

# %%
drop2_df=rename2_df.drop(labels=0)
drop2_df.set_index('States',inplace=True)
#drop2_df.head()
drop2_df.reset_index().head()
# Out:
#        States  AVG_income_2020  AVG_income_2019
# 0     Alabama            57243            59558
# 1      Alaska            78236            83079
# 2     Arizona            70220            74897
# 3    Arkansas            53148            57799
# 4  California            81278            82772

# %%
url_3 ="https://fred.stlouisfed.org/release/tables?rid=249&eid=259515&od="
browser.visit(url_3)
data3_df = pd.read_html(url_3)
df_3=data3_df[0]
df_3.columns = ["Unnamed: 0_level_1","Name","2021","Preceding Period","Year Ago from Period"]
df_3.head()
# Out:
#    Unnamed: 0_level_1               Name   2021  Preceding Period  \
# 0                 NaN  The United States  70784             71186
# 1                 NaN            Alabama  56929             57243
# 2                 NaN             Alaska  81133             78236
# 3                 NaN            Arizona  70821             70220
# 4                 NaN           Arkansas  50784             53148
#
#    Year Ago from Period
# 0                 71186
# 1                 57243
# 2                 78236
# 3                 70220
# 4                 53148

# %%
reduce3_df=df_3.drop(["Unnamed: 0_level_1","Preceding Period","Year Ago from Period"], axis=1)
#reduce3_df.head()
rename3_df = reduce3_df.rename(columns={"Name":"States","2021":"AVG_income_2021"})
rename3_df.head()
# Out:
#               States  AVG_income_2021
# 0  The United States            70784
# 1            Alabama            56929
# 2             Alaska            81133
# 3            Arizona            70821
# 4           Arkansas            50784

# %%
drop3_df=rename3_df.drop(labels=0)
drop3_df.set_index('States',inplace=True)
#drop3_df.head()
drop3_df.reset_index().head()
# Out:
#        States  AVG_income_2021
# 0     Alabama            56929
# 1      Alaska            81133
# 2     Arizona            70821
# 3    Arkansas            50784
# 4  California            81575

# %% [markdown]
# # Merging the income df and ordering the

# %%
#merging
combined1_df= pd.merge(drop0_df,drop1_df, on ="States")
combined1_df
# Out:
#                       AVG_income_2016  AVG_income_2015  AVG_income_2018  \
# States
# Alabama                         53314            50900            53879
# Alaska                          85494            85898            74161
# Arizona                         64468            59751            67201
# Arkansas                        51830            48944            53712
# California                      75235            72774            76055
# Colorado                        79671            76159            78801
# Connecticut                     85720            83355            78561
# Delaware                        65536            66049            70145
# District of Columbia            80141            80133            92521
# Florida                         57779            55836            58959
# Georgia                         60434            58058            60229
# Hawaii                          81440            73778            86433
# Idaho                           63863            59037            63365
# Illinois                        69307            69088            75684
# Indiana                         63332            59447            64621
# Iowa                            66719            69593            74144
# Kansas                          64140            62743            68987
# Kentucky                        51223            48474            58863
# Louisiana                       47641            52516            53919
# Maine                           57418            58044            63295
# Maryland                        83277            84162            93031
# Massachusetts                   81591            77605            93163
# Michigan                        64458            61986            65222
# Minnesota                       79278            78599            77488
# Mississippi                     46402            45786            46159
# Missouri                        62115            67696            66600
# Montana                         64440            58775            62233
# Nebraska                        67035            69158            72911
# Nevada                          62583            59476            66749
# New Hampshire                   86100            86541            87769
# New Jersey                      77303            78173            80033
# New Mexico                      54703            51598            52096
# New York                        69364            66334            72586
# North Carolina                  60701            58091            57583
# North Dakota                    67950            65659            71756
# Ohio                            60951            60955            66500
# Oklahoma                        57516            53837            58732
# Oregon                          66765            69569            74626
# Pennsylvania                    68847            69061            69619
# Rhode Island                    69467            63699            67183
# South Carolina                  61347            53017            61980
# South Dakota                    64863            62972            64158
# Tennessee                       57969            54126            60487
# Texas                           65649            64582            64506
# Utah                            76188            75772            83152
# Vermont                         68687            68037            75599
# Virginia                        75025            70315            83243
# Washington                      79382            76899            86021
# West Virginia                   50077            48973            54566
# Wisconsin                       67535            63384            67574
# Wyoming                         65291            69673            67477
#
#                       AVG_income_2017
# States
# Alabama                         56219
# Alaska                          86196
# Arizona                         65984
# Arkansas                        54988
# California                      77410
# Colorado                        82877
# Connecticut                     82125
# Delaware                        71799
# District of Columbia            89838
# Florida                         58674
# Georgia                         64089
# Hawaii                          81346
# Idaho                           65760
# Illinois                        72913
# Indiana                         64953
# Iowa                            70148
# Kansas                          62889
# Kentucky                        54901
# Louisiana                       48151
# Maine                           58928
# Maryland                        90734
# Massachusetts                   84269
# Michigan                        62342
# Minnesota                       77341
# Mississippi                     47837
# Missouri                        62481
# Montana                         63450
# Nebraska                        65855
# Nevada                          64151
# New Hampshire                   83591
# New Jersey                      78739
# New Mexico                      50401
# New York                        68021
# North Carolina                  54762
# North Dakota                    66500
# Ohio                            67076
# Oklahoma                        57343
# Oregon                          69077
# Pennsylvania                    67736
# Rhode Island                    72285
# South Carolina                  60278
# South Dakota                    62905
# Tennessee                       61128
# Texas                           66417
# Utah                            77135
# Vermont                         70385
# Virginia                        78265
# Washington                      79071
# West Virginia                   51900
# Wisconsin                       70164
# Wyoming                         65803

# %%
combined2_df= pd.merge(combined1_df,drop2_df, on ="States")
combined2_df.head()
# Out:
#             AVG_income_2016  AVG_income_2015  AVG_income_2018  \
# States
# Alabama               53314            50900            53879
# Alaska                85494            85898            74161
# Arizona               64468            59751            67201
# Arkansas              51830            48944            53712
# California            75235            72774            76055
#
#             AVG_income_2017  AVG_income_2020  AVG_income_2019
# States
# Alabama               56219            57243            59558
# Alaska                86196            78236            83079
# Arizona               65984            70220            74897
# Arkansas              54988            53148            57799
# California            77410            81278            82772

# %%
combined3_df= pd.merge(combined2_df,drop3_df, on ="States")
combined3_df.head()
# Out:
#             AVG_income_2016  AVG_income_2015  AVG_income_2018  \
# States
# Alabama               53314            50900            53879
# Alaska                85494            85898            74161
# Arizona               64468            59751            67201
# Arkansas              51830            48944            53712
# California            75235            72774            76055
#
#             AVG_income_2017  AVG_income_2020  AVG_income_2019  AVG_income_2021
# States
# Alabama               56219            57243            59558            56929
# Alaska                86196            78236            83079            81133
# Arizona               65984            70220            74897            70821
# Arkansas              54988            53148            57799            50784
# California            77410            81278            82772            81575

# %%
F_df=combined3_df.reset_index()
F_df.head()
# Out:
#        States  AVG_income_2016  AVG_income_2015  AVG_income_2018  \
# 0     Alabama            53314            50900            53879
# 1      Alaska            85494            85898            74161
# 2     Arizona            64468            59751            67201
# 3    Arkansas            51830            48944            53712
# 4  California            75235            72774            76055
#
#    AVG_income_2017  AVG_income_2020  AVG_income_2019  AVG_income_2021
# 0            56219            57243            59558            56929
# 1            86196            78236            83079            81133
# 2            65984            70220            74897            70821
# 3            54988            53148            57799            50784
# 4            77410            81278            82772            81575

# %%
#ordering the columns
final_combined_df = F_df[["States","AVG_income_2015","AVG_income_2016","AVG_income_2017","AVG_income_2018",
                                  "AVG_income_2019","AVG_income_2020","AVG_income_2021"]]
final_combined_df.head()
# Out:
#        States  AVG_income_2015  AVG_income_2016  AVG_income_2017  \
# 0     Alabama            50900            53314            56219
# 1      Alaska            85898            85494            86196
# 2     Arizona            59751            64468            65984
# 3    Arkansas            48944            51830            54988
# 4  California            72774            75235            77410
#
#    AVG_income_2018  AVG_income_2019  AVG_income_2020  AVG_income_2021
# 0            53879            59558            57243            56929
# 1            74161            83079            78236            81133
# 2            67201            74897            70220            70821
# 3            53712            57799            53148            50784
# 4            76055            82772            81278            81575
